# %% [markdown]
# # Module 1, Final Project, README

# %% [markdown]
# This is a README for the Module 1 Final Project for the DS FT 12-09-19 Cohort.

# %% [markdown]
# # Folder Layout

# %% [markdown]
# The folder layout is as follows...
#
# zippedData
#
# Andy's EDA Notebook.ipynb
#
# Andy's README.ipynb
#
# student.ipynb1
#
# Running
#
# awesome.gif1
#
# CONTRIBUTING.md1
#
# LICENSE.md1
#
# module1_project_rubric.pdf
#
# README.md

# %% [markdown]
# "zippedData" contains a copy of the provided data with the project's initial download/clone from github.
#
# "Andy's EDA Notebook.ipynb" is the main EDA Notebook that was used to explore the data questions in this Project.
#
# "Andy's README.ipynb" is this document and my modified README for this project.
#
# "student.ipynb1" contains a copy of the provided data with the project's initial download/clone from github.
#
# "awesome.gif1" contains a copy of the provided data with the project's initial download/clone from github.
#
# "CONTRIBUTING.md1" contains a copy of the provided data with the project's initial download/clone from github.
#
# "LICENSE.md1" contains a copy of the provided data with the project's initial download/clone from github.
#
# "module1_project_rubric.pdf" contains a copy of the provided data with the project's initial download/clone from
# github.
#
# "README.md" contains a copy of the provided data with the project's initial download/clone from github.
